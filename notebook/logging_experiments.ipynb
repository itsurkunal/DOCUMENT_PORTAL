# %%
print("All ok")
# Out:
# All ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), "logs_dir")

# %%
logs_dir
# Out:
# 'c:\\Users\\ipsit\\Downloads\\Kunal\\DOCUMENT_PORTAL\\notebook\\logs_dir'

# %%
os.makedirs("logs_dir", exist_ok=True)

# %%
logs_dir = "logs_dir"                      # assign the string first
os.makedirs(logs_dir, exist_ok=True)       # then create the folder using it

# %%
LOG_FILE = f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '2026-08-03_20-22-49.log'

# %% [markdown]
# #today
# with today's date log file will be created
#
# #tomorrow
# with tomorrow's date log file will be created

# %%
print(logs_dir, type(logs_dir))
print(LOG_FILE, type(LOG_FILE))
# Out:
# c:\Users\ipsit\Downloads\Kunal\DOCUMENT_PORTAL\notebook\logs_dir <class 'str'>
# 2026-08-03_20-22-49.log <class 'str'>

# %%
os.path.join(logs_dir, LOG_FILE)
# Out:
# 'c:\\Users\\ipsit\\Downloads\\Kunal\\DOCUMENT_PORTAL\\notebook\\logs_dir\\2026-08-03_20-22-49.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[%(asctime)s] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO
)

# %%
logging.getLogger("DocumentPortal")
# Out:
# <Logger DocumentPortal (INFO)>

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")
